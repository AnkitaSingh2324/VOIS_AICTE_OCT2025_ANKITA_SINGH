# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitaSingh2324/Ankita-Singh-airbnb-hotel-analysis-/blob/main/Ankita_Singh_air_bnb_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_excel('/content/1730285881-Airbnb_Open_Data.xlsx')

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee  minimum nights  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102329 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102191 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  float64
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
df[df['neighbourhood group']=='brookln']
# Out:
#          id                                            NAME      host id  \
# 13  1008516  Lovely Room 1, Garden, Best Area, Legal rental  26802410424
#
#    host_identity_verified host name neighbourhood group neighbourhood  \
# 13               verified     Darcy             brookln   South Slope
#
#          lat      long        country  ... service fee  minimum nights  \
# 13  40.66829 -73.98779  United States  ...       116.0             4.0
#
#    number of reviews last review  reviews per month  review rate number  \
# 13             167.0  2019-06-24               1.34                 4.0
#
#     calculated host listings count  availability 365  house_rules license
# 13                             3.0              47.0          NaN     NaN
#
# [1 rows x 26 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(['house_rules','license'],axis=1,inplace=True)

# %%
df['price']=df['price'].astype(str).str.replace('$','',regex=False)
df['service fee']=df['service fee'].astype(str).str.replace('$','',regex=False)

# %%
df['price']=df['price'].str.replace(',','',regex=False)
df['service fee']=df['service fee'].str.replace(',','',regex=False)

# %%
df.rename(columns ={
    'price':'price_$'
},inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.rename(columns ={'service fee':'service_fee_$'},inplace=True)
df['price_$']=df['price_$'].astype(float)
df['service_fee_$']=df['service_fee_$'].astype(float)
df['id']=df['id'].astype(str)
df['host id']=df['host id'].astype(str)
df['last review']=pd.to_datetime(df['last review'])
df['construction year']=df['Construction year'].astype(int)

# %%
df.loc[df['neighbourhood group']=='brookln','neighbourhood group']='Brooklyn'

# %%
df=df.drop(df[df['availability 365']>500].index)

# %%
df.duplicated().value_counts()
# Out:
# False    83796
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83796 entries, 0 to 102057
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              83796 non-null  object
#  1   NAME                            83796 non-null  object
#  2   host id                         83796 non-null  object
#  3   host_identity_verified          83796 non-null  object
#  4   host name                       83796 non-null  object
#  5   neighbourhood group             83796 non-null  object
#  6   neighbourhood                   83796 non-null  object
#  7   lat                             83796 non-null  float64
#  8   long                            83796 non-null  float64
#  9   country                         83796 non-null  object
#  10  country code                    83796 non-null  object
#  11  instant_bookable                83796 non-null  float64
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS(ECA)

# %%
df.describe()
# Out:
#                 lat          long  instant_bookable  Construction year  \
# count  83796.000000  83796.000000      83796.000000       83796.000000
# mean      40.727353    -73.948502          0.497721        2012.489522
# min       40.504560    -74.249840          0.000000        2003.000000
# 25%       40.687660    -73.982110          0.000000        2007.000000
# 50%       40.721335    -73.953710          0.000000        2012.000000
# 75%       40.762580    -73.930790          1.000000        2017.000000
# max       40.916970    -73.705220          1.000000        2022.000000
# std        0.056317      0.050338          0.499998           5.760523
#
#             price_$  service_fee_$  minimum nights  number of reviews  \
# count  83596.000000   83567.000000    83796.000000       83796.000000
# mean     626.342457     125.232436        7.436775          32.226622
# min       50.000000      10.000000     -365.000000           1.000000
# ...

# %% [markdown]
# What are the different propert types in the datasets

# %%
property_type =df['room type'].value_counts().to_frame()
property_type
# Out:
#                  count
# room type
# Entire home/apt  44367
# Private room     37664
# Shared room       1655
# Hotel room         110

# %%
room_type_bar=plt.bar(property_type.index,property_type.loc[:,"count"]);
plt.bar_label(room_type_bar,labels=property_type.loc[:,"count"],padding=4);
plt.ylim(0,50000);
plt.xlabel('room type');
plt.ylabel('room type count');
plt.title('property type and their count in the datasets');

# %% [markdown]
# This bar chart shows the distribution of different room types available in the dataset.
#
# Entire home/apt: This is the most common room type, with over 44,000 listings.
# Private room: This is the second most common type, with over 37,000 listings.
# Shared room: This is significantly less common than the other two, with around 1600 listings.
# Hotel room: This is the least common type, with only 110 listings.
# The chart clearly shows that the majority of listings are either entire homes/apartments or private rooms.

# %% [markdown]
# 2.Which neighborhood group has the highest numbers of listing?

# %%
hood_group=df['neighbourhood group'].value_counts().to_frame()
hood_group
# Out:
#                      count
# neighbourhood group
# Brooklyn             34780
# Manhattan            34735
# Queens               11184
# Bronx                 2276
# Staten Island          821

# %%
hood_group_bar=plt.bar(hood_group.index,hood_group.loc[:,"count"]);
plt.bar_label(hood_group_bar,labels=hood_group.loc[:,"count"],padding =4);
plt.ylim(0,40000);
plt.xlabel('neighbourhood group');
plt.ylabel('number of listings');
plt.title ('which neighbourhood group has the highest number of listings ');

# %% [markdown]
# Which neighborhood group have highest average price for airbnb listings ?

# %%
avg_price=df.groupby('neighbourhood group')['price_$'].mean().sort_values(ascending=False).to_frame()
avg_price_bar=plt.bar(avg_price.index,avg_price.loc[:,"price_$"]);
plt.bar_label(avg_price_bar,label=round(avg_price.loc[:,"price_$"],2),label_type='edge',padding=4);
plt.ylim(0,700);
plt.xlabel('neighbourhood group');
plt.ylabel('average price listings($)');
plt.xticks(rotation=45);
plt.title('Average price per listings ($) in each neighborhood group ');

# %% [markdown]
# Is there a relationship between the construction year of property and price ?

# %%
df.groupby(df['construction year'])['price_$'].mean().to_frame().plot();
plt.xlabel('construction year');
plt.ylabel('average price($)');
plt.title('average price($)for properties in each construction year');

# %% [markdown]
# who are the top 10 hots by calculating  host listing count?

# %%
hosts=df.groupby('host name')['calculated host listings count'].sum().sort_values(ascending=False).nlargest(10).to_frame()
hosts_bar=plt.bar(hosts.index,hosts.loc[:,"calculated host listings count"]);
plt.bar_label(hosts_bar,label=hosts.loc[:,"calculated host listings count"],label_type='edge',padding=3);
plt.xlabel('hosts name');
plt.ylabel('calculated hosts listings count');
plt.xticks(rotation=80);
plt.ylim(0,120000);
plt.title('top 10 hosts by calculated host listingscount');

# %% [markdown]
# Are hosts with verified identities most likely to recieve positive review ?

# %%
review=df.groupby('host_identity_verified')['review rate number'].mean().sort_values(ascending=False).to_frame()
review
# Out:
#                         review rate number
# host_identity_verified
# verified                          3.283856
# unconfirmed                       3.273786

# %%
review_bar=plt.bar(review.index,review.loc[:,"review rate number"]);
plt.bar_label(review_bar,labels=round(review.loc[:,"review rate number"],2),padding=4);
plt.ylim(0,4);
plt.xlabel('host verification status')
plt.ylabel('average review rate number');
plt.title('average review rate for each verification statistics');

# %%
sns.boxplot(data=df,x="host_identity_verified",y="review rate number");
plt.xlabel('hosts verification status');
plt.ylabel('review rate number');
plt.title('average review rate for each verifications status');

# %% [markdown]
# Is there a correlation between the price of a listing and its service fee?

# %%
df['price_$'].corr(df['service_fee_$'])
# Out:
# np.float64(0.9999909082976466)

# %%
sns.regplot(df,x='price_$',y='service_fee_$');
plt.xlabel('price($)');
plt.ylabel('service fee($)');
plt.title('a regression plot showingthe correlation of the price and service fee');

# %% [markdown]
# What is the average  review rate bumber for listing , and does it very based on the neighborhood group and room type?

# %%
ARRN=df.groupby(['neighbourhood group','room type'])['review rate number'].mean().to_frame()
ARRN
# Out:
#                                      review rate number
# neighbourhood group room type
# Bronx               Entire home/apt            3.379863
#                     Private room               3.312548
#                     Shared room                3.356322
# Brooklyn            Entire home/apt            3.243013
#                     Hotel room                 3.833333
#                     Private room               3.274774
#                     Shared room                3.322368
# Manhattan           Entire home/apt            3.268940
#                     Hotel room                 3.500000
#                     Private room               3.285628
#                     Shared room                3.252976
# Queens              Entire home/apt            3.347437
#                     Hotel room                 3.750000
#                     Private room               3.311761
#                     Shared room                3.327402
# ...

# %%
plt.figure(figsize=[12,10]);
sns.barplot(data=df,x='neighbourhood group',y='review rate number',hue='room type');
plt.xlabel('neighbourhood group');
plt.ylabel('average review rate');
plt.title('average review for each room/property type in each neighbourhoodgroup');

# %% [markdown]
# Are the hosts with a higher calculated hosts listing counts more likely to maintain higher availability throughout the year?

# %%
sns.regplot(data=df,x='calculated host listings count',y='availability 365');
plt.xlabel('calculated hosts listings');
plt.ylabel('availability 365');
plt.title('a regression plot of the relationships between hosts listing count and availability 365');

# %%
df['calculated host listings count'].corr(df['availability 365'])
# Out:
# np.float64(0.1353372562905428)

# %% [markdown]
# Property Types: "Entire home/apt" and "Private room" are the most common property types in the dataset.
# Neighbourhood Group Listings: Brooklyn and Manhattan have the highest number of listings, very close in count.
# Average Price by Neighbourhood Group: Queens and the Bronx have slightly higher average prices compared to Brooklyn, Manhattan, and Staten Island.
# Construction Year and Price: There appears to be some fluctuation in average price based on the construction year, but no strong linear relationship is evident from the plot.
# Top Hosts: "Sonder (NYC)" has a significantly higher number of calculated host listings compared to other hosts in the top 10.
# Host Identity Verification and Review Rate: There is a very slight difference in the average review rate between verified and unconfirmed hosts, with verified hosts having a marginally higher average. The boxplot also shows similar distributions for both groups.
# Price and Service Fee Correlation: There is a very strong positive correlation (close to 1) between the price of a listing and its service fee, as shown by the regression plot and the correlation coefficient.
# Review Rate by Neighbourhood Group and Room Type: The average review rate varies across neighbourhood groups and room types. Hotel rooms in Brooklyn and Queens seem to have higher average review rates compared to other room types in those areas.
# Host Listing Count and Availability: There is a weak positive correlation between the calculated host listings count and availability. The regression plot shows a scattered distribution, indicating that having more listings does not strongly guarantee higher availability.
